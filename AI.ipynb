# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/longformer/scripts
# Out:
# /content/drive/MyDrive/longformer/scripts

# %%
# !pip3 install virtualenv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 68.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 49.1 MB/s eta 0:00:00
# ...

# %%
# !virtualenv ai -p python3.8
# Out:
# created virtual environment CPython3.8.10.final.0-64 in 40319ms
#   creator CPython3Posix(dest=/content/drive/MyDrive/longformer/scripts/ai, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
# ...

# %%
# !source ai/bin/activate; python --version
# Out:
# Python 3.8.10

# %%
# !source ai/bin/activate; pip install -r /content/drive/MyDrive/longformer/requirements.txt
# Out:
# ...
#   Cloning http://github.com/ibeltagy/transformers.git (to revision longformer_encoder_decoder) to /tmp/pip-install-gcywxa14/transformers_458e31d67a8543c0a4a78472c391fd87
#   Running command git clone --filter=blob:none --quiet http://github.com/ibeltagy/transformers.git /tmp/pip-install-gcywxa14/transformers_458e31d67a8543c0a4a78472c391fd87
# ...
#   Running command git checkout -b longformer_encoder_decoder --track origin/longformer_encoder_decoder
# ...
#   Switched to a new branch 'longformer_encoder_decoder'
#   Branch 'longformer_encoder_decoder' set up to track remote branch 'longformer_encoder_decoder' from 'origin'.
#   Resolved http://github.com/ibeltagy/transformers.git to commit 52d6236dc15ad5142b4146ff74d2ec973fa3da22
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning http://github.com/ibeltagy/pytorch-lightning.git (to revision v0.8.5_fixes) to /tmp/pip-install-gcywxa14/pytorch-lightning_1de547688f7a4c4c9eac7b34fb8b3fb0
# ...

# %%
# !source ai/bin/activate; pip install datasets

# %%
# !source ai/bin/activate; pip list
# Out:
# Package                  Version
# ------------------------ ----------
# absl-py                  1.4.0
# aiohttp                  3.8.4
# aiosignal                1.3.1
# async-timeout            4.0.2
# attrs                    23.1.0
# cachetools               5.3.1
# certifi                  2023.5.7
# charset-normalizer       3.2.0
# click                    8.1.4
# cmake                    3.26.4
# datasets                 2.13.1
# dill                     0.3.6
# filelock                 3.12.2
# frozenlist               1.3.3
# fsspec                   2023.6.0
# future                   0.18.3
# google-auth              2.21.0
# google-auth-oauthlib     1.0.0
# grpcio                   1.56.0
# huggingface-hub          0.16.4
# idna                     3.4
# imageio                  2.31.1
# importlib-metadata       6.8.0
# Jinja2                   3.1.2
# joblib                   1.3.1
# lit                      16.0.6
# Markdown                 3.4.3
# ...

# %%
# !source ai/bin/activate; python summarization.py
# Out:
# Downloading: 100% 1.55k/1.55k [00:00<00:00, 5.60MB/s]
# Downloading: 100% 899k/899k [00:01<00:00, 825kB/s]
# Downloading: 100% 456k/456k [00:00<00:00, 525kB/s]
# Downloading: 100% 558M/558M [00:08<00:00, 68.9MB/s]
# ...
# ...
# ...
# Extracting data files: 100% 2/2 [02:59<00:00, 89.50s/it]
# Dataset scientific_papers downloaded and prepared to /root/.cache/huggingface/datasets/scientific_papers/arxiv/1.1.1/306757013fb6f37089b6a75469e6638a553bd9f009484938d8f75a4c5e84206f. Subsequent calls will reuse this data.
# 100% 3/3 [00:01<00:00,  1.67it/s]
# ...
